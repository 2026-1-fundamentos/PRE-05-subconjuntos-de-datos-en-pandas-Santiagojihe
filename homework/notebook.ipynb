# %% [markdown]
# Este es un titulo de primer nivel
#
# este es un texto de ejemplo con una ecuación x^2 + 1
#
# - viñeta 1
#   - nivel interior
# - viñeta 2

# %%
import pandas as pd  #  type: ignore

pd.set_option("display.notebook_repr_html", False)

# %%
print("hello world")
